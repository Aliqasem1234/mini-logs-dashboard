# %% [markdown]
# # visar tabell + enkel räkning per nivå

# %%
from fetch_logs import hamta_loggar
import matplotlib.pyplot as plt
import pandas as pd

df = hamta_loggar(antal_per_sida=200)
df['timestamp'] = pd.to_datetime(df['timestamp'])
df.head()
# Out:
# c:\Users\Lenovo\Desktop\Logging_system\fetch_logs.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   with psycopg.connect(**DB_CONFIG) as conn:
#    id                  timestamp    level           service  \
# 0  18 2026-01-20 16:10:19.302615    ERROR  InventoryService
# 1  17 2026-01-20 16:10:18.326861  WARNING       AuthService
# 2  16 2026-01-20 16:10:18.052591     INFO    PaymentService
# 3  15 2026-01-19 22:42:04.061287    ERROR        testserves
# 4  14 2026-01-19 21:21:25.045888    ERROR       testservice
#
#                          message                             context
# 0         Failed to update stock        {'sku': 'A123', 'delta': -5}
# 1  Login attempt from blocked IP                                  {}
# 2              Payment processed  {'amount': 100, 'currency': 'SEK'}
# ...

# %%
# antal rader per level
if not df.empty:
    ax = df['level'].value_counts().plot.barh(title='Antal loggrader')
    plt.xlabel('Antal')
    plt.show()
else:
    print('Inga loggar att visa')
# Out:
# Inga loggar att visa

# %%
from fetch_logs import hamta_loggar, rakna_loggar

print('Total  :', rakna_loggar())
print('Page 1 :', hamta_loggar(sida=1, antal_per_sida=10).shape)
# Out:
# Total  : 18
# Page 1 : (10, 6)
# c:\Users\Lenovo\Desktop\Logging_system\fetch_logs.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   with psycopg.connect(**DB_CONFIG) as conn:
